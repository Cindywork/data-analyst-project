# %% [markdown]
# # Global Imports

# %%
import pylab
import calendar
import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats
import missingno as msno
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import kendalltau
import warnings
matplotlib.style.use('ggplot')
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### import data

# %%
train = pd.read_csv('Projects_data/train_2016_v2.csv', parse_dates=["transactiondate"])
properties = pd.read_csv('Projects_data/properties_2016.csv')

# %% [markdown]
# ### shape of the Dataset

# %%
print('Shape of train', train.shape)
print('Shape of properties', properties.shape)

# %% [markdown]
# ### Merge Train and Properties

# %%
merged = pd.merge(train, properties, on= 'parcelid', how = 'left')

# %%
merged.head(5).transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-093a07bf55b0> in <module>()
# ----> 1 merged.head(5).transpose()
#
# NameError: name 'merged' is not defined

# %% [markdown]
# ### Datatypes Visulization

# %%
data_type_df = pd.DataFrame(merged.dtypes.value_counts()).reset_index().rename(columns={"index":"variableType", 0:"count"})
fig, ax = plt.subplots()
fig.set_size_inches(20,5)
sn.barplot(data=data_type_df, x='variableType', y='count', ax=ax, color = '#34495e')
#ax.set(xlabel = 'Variable Type', ylabel='Count', title='Variables Count Across Datatype')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-39f39ed70aec> in <module>()
# ----> 1 data_type_df = pd.DataFrame(merged.dtypes.value_counts()).reset_index().rename(columns={"index":"variableType", 0:"count"})
#       2 fig, ax = plt.subplots()
#       3 fig.set_size_inches(20,5)
#       4 sn.barplot(data=data_type_df, x='variableType', y='count', ax=ax, color = '#34495e')
#       5 #ax.set(xlabel = 'Variable Type', ylabel='Count', title='Variables Count Across Datatype')
#
# NameError: name 'merged' is not defined

# %% [markdown]
# ### Missing Value Analysis

# %%
missing_value_columns = merged.columns[merged.isnull().any()].tolist()
msno.bar(merged[missing_value_columns], figsize = (20,8), color='#34495e', fontsize= 12, labels= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6ba32f7c3b0c> in <module>()
# ----> 1 missing_value_columns = merged.columns[merged.isnull().any()].tolist()
#       2 msno.bar(merged[missing_value_columns], figsize = (20,8), color='#34495e', fontsize= 12, labels= True)
#
# NameError: name 'merged' is not defined

# %%
msno.matrix(merged[missing_value_columns], width_ratios=(10,1), \
            figsize=(20,8), color = (0,0,0), fontsize= 12, sparkline=True, labels=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-70d048ab2d85> in <module>()
# ----> 1 msno.matrix(merged[missing_value_columns], width_ratios=(10,1),             figsize=(20,8), color = (0,0,0), fontsize= 12, sparkline=True, labels=True)
#
# NameError: name 'merged' is not defined

# %%
msno.heatmap(merged[missing_value_columns], figsize=(20,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6b6b1d3e29cb> in <module>()
# ----> 1 msno.heatmap(merged[missing_value_columns], figsize=(20,20))
#
# NameError: name 'merged' is not defined

# %% [markdown]
# ### Top Features Selection

# %%
from sklearn import model_selection, preprocessing
import xgboost as xgb
import warnings
warnings.filterwarnings("ignore")

# %%
mergedFilterd = merged.fillna(-999)
for f in mergedFilterd.columns:
    if mergedFilterd[f].dtype=='object':
        lbl = preprocessing.LabelEncoder()                         
        lbl.fit(list(mergedFilterd[f].values))                               #fill label encoder  
        mergedFilterd[f] = lbl.transform(list(mergedFilterd[f].values))      #fill with 0

# %%
train_y = mergedFilterd['logerror'].values
train_X = mergedFilterd.drop(['parcelid', 'transactiondate', 'logerror'], axis=1)

# %%
xgb_params = {
    'eta':0.05,
    'max_depth':8,
    'subsample':0.7,
    'colsample_bytree':0.7,
    'objective':'reg:linear',
    'evalmetric': 'rmse',
    'silent':1
}
dtrain = xgb.DMatrix(train_X, train_y, feature_names = train_X.columns.values) #load data 
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=100)

# %%
featureImportance = model.get_fscore()
features = pd.DataFrame()
features['features'] = featureImportance.keys()
features['importance'] = featureImportance.values()
features.sort_values(by=['importance'], ascending=False, inplace=True)
fig,ax = plt.subplots()
fig.set_size_inches(20,10)
plt.xticks(rotation=90)
sn.barplot(data=features.head(15), x='importance', y='features', ax=ax, orient='h', color='#34495e')

# %%
features.head(5)
# Out:
#                         features  importance
# 7   calculatedfinishedsquarefeet         790
# 11                      latitude         684
# 24             lotsizesquarefeet         597
# 2                      longitude         560
# 12    structuretaxvaluedollarcnt         522

# %% [markdown]
# ### Correlation Analysis

# %%
topFeatures = features['features'].tolist()[:20]
corrMatt = merged[topFeatures].corr()
mask = np.array(corrMatt)
mask[np.tril_indices_from(mask)] = False 
fig, ax = plt.subplots()
fig.set_size_inches(20,10)
sn.heatmap(corrMatt, mask=mask, vmax=.8, square=True) #图不对啊！

# %%
mask
# Out:
# array([[ 0.00000000e+00,  9.32097026e-03, -4.87698257e-02,
#         -2.23685709e-02,  7.16488519e-01,  5.89022465e-01,
#          4.58550189e-01,  6.00018181e-01,  7.72552605e-01,
#          6.32034654e-01,  2.11640900e-01,  1.00000000e+00,
#          2.28895066e-02,  5.86767962e-02,  5.87925683e-02,
#         -1.58691131e-01, -4.18338597e-02,  5.96669511e-02,
#          1.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  9.19478307e-02,
#         -5.94096577e-01, -1.35478096e-02, -7.84108737e-02,
#         -1.47394117e-01, -1.12393595e-01,  2.27110129e-02,
#          6.63310558e-02, -7.47465984e-03,  1.08039925e-02,
#          2.04810810e-04, -7.01182362e-02, -7.04581751e-02,
#         -1.34658567e-01, -8.70537169e-03, -4.17596086e-01,
#          4.39168682e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -6.57071814e-02,  8.65499675e-03, -2.20377098e-02,
#         -3.40302275e-02, -2.13467292e-02, -1.96835157e-04,
#         -1.13983710e-01,  1.18078170e-01, -4.67064051e-02,
#         -3.74758593e-03, -7.90999731e-02, -7.85026060e-02,
#         -8.65151132e-02, -1.18549814e-02, -9.07727585e-02,
#          1.25495200e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -5.98065422e-02, -3.51536760e-02,
#         -4.08737713e-03, -2.46816299e-02, -1.83465961e-02,
#         -4.87907384e-03,  6.89770095e-02, -2.11179212e-02,
#          3.68014436e-02, -3.27581773e-01, -3.25381075e-01,
#          1.35084271e-01,  9.95973253e-03,  4.15024647e-01,
#         -6.16080002e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  7.95013536e-01,
#          6.23291904e-01,  8.26052216e-01,  5.86640601e-01,
#          3.05405302e-01,  2.99695983e-01,  7.44048406e-01,
#          2.10612151e-03,  3.81094657e-02,  3.85073031e-02,
#         -1.05381730e-01, -3.07089593e-02, -4.73237194e-02,
#          4.23237974e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          9.02712529e-01,  9.49375838e-01,  4.61899537e-01,
#          2.39117936e-01,  1.15647189e-01,  6.12495725e-01,
#          1.43351731e-03, -3.10461270e-02, -3.03956267e-02,
#         -4.20049657e-02, -2.66245554e-02, -2.82510437e-02,
#          2.91227171e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  9.55335769e-01,  3.53806390e-01,
#          1.73205291e-01,  3.94926467e-02,  4.80463118e-01,
#          6.80239379e-03, -2.03656577e-03, -1.80109150e-03,
#         -1.13484174e-02, -1.37340436e-02,  2.71691210e-02,
#          1.94817664e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  4.76362838e-01,
#          2.41329204e-01,  1.40939510e-01,  6.26051888e-01,
#          5.68935212e-03,  1.24417821e-02,  1.30388661e-02,
#         -4.67084754e-02, -2.13065437e-02, -1.10192840e-03,
#          2.87585939e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          6.46119839e-01,  3.68061368e-01,  7.99372012e-01,
#          1.22646179e-02,  9.71273435e-03,  1.30776118e-02,
#         -2.59747637e-01, -3.72421513e-02, -3.74786635e-02,
#          6.33630672e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  4.08712077e-02,  6.57598886e-01,
#          1.48742515e-02,  2.41896311e-02,  2.81700188e-02,
#         -2.57358574e-02, -2.21655805e-02,  7.53268984e-02,
#          6.15171617e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.58530089e-01,
#          4.28288278e-02,  2.43203480e-01,  2.44000554e-01,
#         -4.24891001e-01, -4.83594418e-02, -7.48846095e-02,
#          1.51646451e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          2.33190624e-02,  7.65232226e-02,  7.66929481e-02,
#         -1.96411483e-01, -4.16785373e-02,  6.07561538e-02,
#                     nan],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  5.40505873e-02,  5.38076504e-02,
#         -1.04359000e-02, -9.44581730e-03,  1.38339515e-02,
#          5.65353156e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  9.99821942e-01,
#         -6.38693915e-02, -3.12581500e-02,  8.00300409e-01,
#          1.08255549e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -4.44722751e-02, -3.13883525e-02,  7.97531055e-01,
#          1.07971578e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  3.76034900e-02,  8.10805029e-03,
#         -2.12023775e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -2.80137149e-02,
#         -6.38335104e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -4.19820798e-03],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00]])

# %%
corrMatt
# Out:
#                               calculatedfinishedsquarefeet  latitude  \
# calculatedfinishedsquarefeet                      1.000000  0.009321
# latitude                                          0.009321  1.000000
# lotsizesquarefeet                                -0.048770  0.091948
# longitude                                        -0.022369 -0.594097
# structuretaxvaluedollarcnt                        0.716489 -0.013548
# taxamount                                         0.589022 -0.078411
# landtaxvaluedollarcnt                             0.458550 -0.147394
# taxvaluedollarcnt                                 0.600018 -0.112394
# bathroomcnt                                       0.772553  0.022711
# bedroomcnt                                        0.632035  0.066331
# yearbuilt                                         0.211641 -0.007475
# finishedsquarefeet12                              1.000000  0.010804
# regionidzip                                       0.022890  0.000205
# rawcensustractandblock                            0.058677 -0.070118
# censustractandblock                               0.058793 -0.070458
# buildingqualitytypeid                            -0.158691 -0.134659
# regionidcity                                     -0.041834 -0.008705
# airconditioningtypeid                             0.059667 -0.417596
# finishedsquarefeet15                              1.000000  0.043917
#
#                               lotsizesquarefeet  longitude  \
# calculatedfinishedsquarefeet          -0.048770  -0.022369
# latitude                               0.091948  -0.594097
# lotsizesquarefeet                      1.000000  -0.065707
# longitude                             -0.065707   1.000000
# structuretaxvaluedollarcnt             0.008655  -0.059807
# taxamount                             -0.022038  -0.035154
# landtaxvaluedollarcnt                 -0.034030  -0.004087
# taxvaluedollarcnt                     -0.021347  -0.024682
# bathroomcnt                           -0.000197  -0.018347
# bedroomcnt                            -0.113984  -0.004879
# yearbuilt                              0.118078   0.068977
# finishedsquarefeet12                  -0.046706  -0.021118
# regionidzip                           -0.003748   0.036801
# rawcensustractandblock                -0.079100  -0.327582
# censustractandblock                   -0.078503  -0.325381
# buildingqualitytypeid                 -0.086515   0.135084
# regionidcity                          -0.011855   0.009960
# airconditioningtypeid                 -0.090773   0.415025
# finishedsquarefeet15                   0.125495  -0.061608
#
#                               structuretaxvaluedollarcnt  taxamount  \
# calculatedfinishedsquarefeet                    0.716489   0.589022
# latitude                                       -0.013548  -0.078411
# lotsizesquarefeet                               0.008655  -0.022038
# longitude                                      -0.059807  -0.035154
# structuretaxvaluedollarcnt                      1.000000   0.795014
# taxamount                                       0.795014   1.000000
# landtaxvaluedollarcnt                           0.623292   0.902713
# taxvaluedollarcnt                               0.826052   0.949376
# bathroomcnt                                     0.586641   0.461900
# bedroomcnt                                      0.305405   0.239118
# yearbuilt                                       0.299696   0.115647
# finishedsquarefeet12                            0.744048   0.612496
# regionidzip                                     0.002106   0.001434
# rawcensustractandblock                          0.038109  -0.031046
# censustractandblock                             0.038507  -0.030396
# buildingqualitytypeid                          -0.105382  -0.042005
# regionidcity                                   -0.030709  -0.026625
# airconditioningtypeid                          -0.047324  -0.028251
# finishedsquarefeet15                            0.423238   0.291227
#
#                               landtaxvaluedollarcnt  taxvaluedollarcnt  \
# calculatedfinishedsquarefeet               0.458550           0.600018
# latitude                                  -0.147394          -0.112394
# lotsizesquarefeet                         -0.034030          -0.021347
# longitude                                 -0.004087          -0.024682
# structuretaxvaluedollarcnt                 0.623292           0.826052
# taxamount                                  0.902713           0.949376
# landtaxvaluedollarcnt                      1.000000           0.955336
# taxvaluedollarcnt                          0.955336           1.000000
# bathroomcnt                                0.353806           0.476363
# bedroomcnt                                 0.173205           0.241329
# yearbuilt                                  0.039493           0.140940
# finishedsquarefeet12                       0.480463           0.626052
# regionidzip                                0.006802           0.005689
# rawcensustractandblock                    -0.002037           0.012442
# censustractandblock                       -0.001801           0.013039
# buildingqualitytypeid                     -0.011348          -0.046708
# regionidcity                              -0.013734          -0.021307
# airconditioningtypeid                      0.027169          -0.001102
# finishedsquarefeet15                       0.194818           0.287586
#
#                               bathroomcnt  bedroomcnt  yearbuilt  \
# calculatedfinishedsquarefeet     0.772553    0.632035   0.211641
# latitude                         0.022711    0.066331  -0.007475
# lotsizesquarefeet               -0.000197   -0.113984   0.118078
# longitude                       -0.018347   -0.004879   0.068977
# structuretaxvaluedollarcnt       0.586641    0.305405   0.299696
# taxamount                        0.461900    0.239118   0.115647
# landtaxvaluedollarcnt            0.353806    0.173205   0.039493
# taxvaluedollarcnt                0.476363    0.241329   0.140940
# bathroomcnt                      1.000000    0.646120   0.368061
# bedroomcnt                       0.646120    1.000000   0.040871
# yearbuilt                        0.368061    0.040871   1.000000
# finishedsquarefeet12             0.799372    0.657599   0.258530
# regionidzip                      0.012265    0.014874   0.042829
# rawcensustractandblock           0.009713    0.024190   0.243203
# censustractandblock              0.013078    0.028170   0.244001
# buildingqualitytypeid           -0.259748   -0.025736  -0.424891
# regionidcity                    -0.037242   -0.022166  -0.048359
# airconditioningtypeid           -0.037479    0.075327  -0.074885
# finishedsquarefeet15             0.633631    0.615172   0.151646
#
#                               finishedsquarefeet12  regionidzip  \
# calculatedfinishedsquarefeet              1.000000     0.022890
# latitude                                  0.010804     0.000205
# lotsizesquarefeet                        -0.046706    -0.003748
# longitude                                -0.021118     0.036801
# structuretaxvaluedollarcnt                0.744048     0.002106
# taxamount                                 0.612496     0.001434
# landtaxvaluedollarcnt                     0.480463     0.006802
# taxvaluedollarcnt                         0.626052     0.005689
# bathroomcnt                               0.799372     0.012265
# bedroomcnt                                0.657599     0.014874
# yearbuilt                                 0.258530     0.042829
# finishedsquarefeet12                      1.000000     0.023319
# regionidzip                               0.023319     1.000000
# rawcensustractandblock                    0.076523     0.054051
# censustractandblock                       0.076693     0.053808
# buildingqualitytypeid                    -0.196411    -0.010436
# regionidcity                             -0.041679    -0.009446
# airconditioningtypeid                     0.060756     0.013834
# finishedsquarefeet15                           NaN     0.056535
#
#                               rawcensustractandblock  censustractandblock  \
# calculatedfinishedsquarefeet                0.058677             0.058793
# latitude                                   -0.070118            -0.070458
# lotsizesquarefeet                          -0.079100            -0.078503
# longitude                                  -0.327582            -0.325381
# structuretaxvaluedollarcnt                  0.038109             0.038507
# taxamount                                  -0.031046            -0.030396
# landtaxvaluedollarcnt                      -0.002037            -0.001801
# taxvaluedollarcnt                           0.012442             0.013039
# bathroomcnt                                 0.009713             0.013078
# bedroomcnt                                  0.024190             0.028170
# yearbuilt                                   0.243203             0.244001
# finishedsquarefeet12                        0.076523             0.076693
# regionidzip                                 0.054051             0.053808
# rawcensustractandblock                      1.000000             0.999822
# censustractandblock                         0.999822             1.000000
# buildingqualitytypeid                      -0.063869            -0.044472
# regionidcity                               -0.031258            -0.031388
# airconditioningtypeid                       0.800300             0.797531
# finishedsquarefeet15                        0.010826             0.010797
#
#                               buildingqualitytypeid  regionidcity  \
# calculatedfinishedsquarefeet              -0.158691     -0.041834
# latitude                                  -0.134659     -0.008705
# lotsizesquarefeet                         -0.086515     -0.011855
# longitude                                  0.135084      0.009960
# structuretaxvaluedollarcnt                -0.105382     -0.030709
# taxamount                                 -0.042005     -0.026625
# landtaxvaluedollarcnt                     -0.011348     -0.013734
# taxvaluedollarcnt                         -0.046708     -0.021307
# bathroomcnt                               -0.259748     -0.037242
# bedroomcnt                                -0.025736     -0.022166
# yearbuilt                                 -0.424891     -0.048359
# finishedsquarefeet12                      -0.196411     -0.041679
# regionidzip                               -0.010436     -0.009446
# rawcensustractandblock                    -0.063869     -0.031258
# censustractandblock                       -0.044472     -0.031388
# buildingqualitytypeid                      1.000000      0.037603
# regionidcity                               0.037603      1.000000
# airconditioningtypeid                      0.008108     -0.028014
# finishedsquarefeet15                      -0.212024     -0.063834
#
#                               airconditioningtypeid  finishedsquarefeet15
# calculatedfinishedsquarefeet               0.059667              1.000000
# latitude                                  -0.417596              0.043917
# lotsizesquarefeet                         -0.090773              0.125495
# longitude                                  0.415025             -0.061608
# structuretaxvaluedollarcnt                -0.047324              0.423238
# taxamount                                 -0.028251              0.291227
# landtaxvaluedollarcnt                      0.027169              0.194818
# taxvaluedollarcnt                         -0.001102              0.287586
# bathroomcnt                               -0.037479              0.633631
# bedroomcnt                                 0.075327              0.615172
# yearbuilt                                 -0.074885              0.151646
# finishedsquarefeet12                       0.060756                   NaN
# regionidzip                                0.013834              0.056535
# rawcensustractandblock                     0.800300              0.010826
# censustractandblock                        0.797531              0.010797
# buildingqualitytypeid                      0.008108             -0.212024
# regionidcity                              -0.028014             -0.063834
# airconditioningtypeid                      1.000000             -0.004198
# finishedsquarefeet15                      -0.004198              1.000000

# %% [markdown]
# ### Multicollinearity Analysis

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings
warnings.filterwarnings('ignore')

# %%
def calculate_vif_(X):
    variables = list(X.columns)
    vif = {}
    for ix, variable in enumerate(list(X.columns)):
        vif[variable] = variance_inflation_factor(exog=X.values, exog_idx=ix)
    return vif

# %%
numericalCol = []
for f in merged.columns:
    if merged[f].dtype!='object' and f not in ['parcelid', 'transactiondate', 'logerror']:
        numericalCol.append(f)
mergedFilterd = merged[numericalCol].fillna(-999)
vifDict = calculate_vif_(mergedFilterd)

# %%
vifDf = pd.DataFrame()
vifDf['variables'] = vifDict.keys()
vifDf['vifScore'] = vifDict.values()
vifDf.sort_values(by=['vifScore'], ascending=False, inplace=True)
vifDf
# Out:
#                        variables      vifScore
# 11          finishedsquarefeet12  2.817303e+11
# 10  calculatedfinishedsquarefeet  6.320323e+09
# 25                       poolcnt  6.110627e+09
# 29                   pooltypeid7  4.518148e+09
# 13          finishedsquarefeet15  2.163587e+09
# 15           finishedsquarefeet6  1.241104e+09
# 46             taxvaluedollarcnt  1.287209e+08
# 28                   pooltypeid2  8.722728e+07
# 12          finishedsquarefeet13  8.488108e+07
# 48         landtaxvaluedollarcnt  6.705584e+07
# 7              calculatedbathnbr  3.991585e+07
# 18                   fullbathcnt  3.873717e+07
# 45    structuretaxvaluedollarcnt  1.826265e+07
# 16                          fips  1.194701e+04
# 31        rawcensustractandblock  1.180960e+04
# 9       finishedfloor1squarefeet  3.409552e+02
# 14          finishedsquarefeet50  3.278200e+02
# 38           threequarterbathnbr  8.474181e+01
# 33                regionidcounty  4.937748e+01
# 40                       unitcnt  4.933669e+01
# 19                  garagecarcnt  3.975271e+01
# 20               garagetotalsqft  3.303883e+01
# 6          buildingqualitytypeid  2.535996e+01
# 37                   storytypeid  1.712093e+01
# 2                   basementsqft  1.697714e+01
# 36                       roomcnt  1.457494e+01
# 44               numberofstories  1.437963e+01
# 49                     taxamount  1.071210e+01
# 21         heatingorsystemtypeid  8.090616e+00
# 39        typeconstructiontypeid  6.606747e+00
# 1       architecturalstyletypeid  6.493447e+00
# 30         propertylandusetypeid  5.175406e+00
# 23                     longitude  3.998885e+00
# 3                    bathroomcnt  3.674503e+00
# 43                     yearbuilt  3.572610e+00
# 22                      latitude  2.800126e+00
# 4                     bedroomcnt  2.709586e+00
# 5            buildingclasstypeid  2.609186e+00
# 17                  fireplacecnt  2.192863e+00
# 0          airconditioningtypeid  1.791656e+00
# 41            yardbuildingsqft17  1.665187e+00
# 51           censustractandblock  1.617626e+00
# 26                   poolsizesum  1.433430e+00
# 8                     decktypeid  1.130354e+00
# 24             lotsizesquarefeet  1.094975e+00
# 34          regionidneighborhood  1.092488e+00
# 42            yardbuildingsqft26  1.035673e+00
# 27                  pooltypeid10  1.023623e+00
# 32                  regionidcity  1.023135e+00
# 35                   regionidzip  1.015609e+00
# 50            taxdelinquencyyear  1.009877e+00
# 47                assessmentyear  0.000000e+00

# %%
validVariables = vifDf[vifDf['vifScore']<=5]
variablesWithMC = vifDf[vifDf['vifScore']>5]

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(20,8)
sn.barplot(data=validVariables, x='vifScore', y='variables', ax=ax1, orient='h', color='#34495e')
sn.barplot(data=variablesWithMC.head(5), x='vifScore', y='variables', ax=ax2, orient='h', color='#34495e')
ax1.set(xlabel='VIF Scores', ylabel='Features',title="Valid Variables Without Multicollinearity")
ax2.set(xlabel='VIF Scores', ylabel='Features',title="Variables Which Exhibit Multicollinearity") #?
# Out:
# [Text(0,0.5,'Features'),
#  Text(0.5,0,'VIF Scores'),
#  Text(0.5,1,'Variables Which Exhibit Multicollinearity')]

# %% [markdown]
# ### Univariate Analysis
# #### Dependent variable logerror follows nice normal distribution

# %%
ulimit = np.percentile(merged.logerror.values, 99)
llimit = np.percentile(merged.logerror.values, 1)

# %%
ulimit
# Out:
# 0.4638819999999963

# %%
llimit
# Out:
# -0.3425
