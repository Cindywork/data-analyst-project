# %% [markdown]
# # Global Imports

# %%
import pylab
import calendar
import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats
import missingno as msno
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import kendalltau
import warnings
matplotlib.style.use('ggplot')
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### import data

# %%
train = pd.read_csv('Projects_data/train_2016_v2.csv', parse_dates=["transactiondate"])
properties = pd.read_csv('Projects_data/properties_2016.csv')

# %% [markdown]
# ### shape of the Dataset

# %%
print('Shape of train', train.shape)
print('Shape of properties', properties.shape)
# Out:
# Shape of train (90275, 3)
# Shape of properties (2985217, 58)

# %% [markdown]
# ### Merge Train and Properties

# %%
merged = pd.merge(train, properties, on= 'parcelid', how = 'left')

# %%
merged.transpose()
# Out:
#                                             0                    1      \
# parcelid                                 11016594             14366692
# logerror                                   0.0276              -0.1684
# transactiondate               2016-01-01 00:00:00  2016-01-01 00:00:00
# airconditioningtypeid                           1                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     2                  3.5
# bedroomcnt                                      3                    4
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                           4                  NaN
# calculatedbathnbr                               2                  3.5
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet                 1684                 2263
# finishedsquarefeet12                         1684                 2263
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6037                 6059
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                     2                    3
# garagecarcnt                                  NaN                    2
# garagetotalsqft                               NaN                  468
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                           2                  NaN
# latitude                               3.4281e+07          3.36681e+07
# longitude                            -1.18489e+08         -1.17678e+08
# lotsizesquarefeet                            7528                 3643
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                    0100                    1
# propertylandusetypeid                         261                  261
# propertyzoningdesc                           LARS                  NaN
# rawcensustractandblock                6.03711e+07          6.05905e+07
# regionidcity                                12447                32380
# regionidcounty                               3101                 1286
# regionidneighborhood                        31817                  NaN
# regionidzip                                 96370                96962
# roomcnt                                         0                    0
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                    1
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                         1                  NaN
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1959                 2014
# numberofstories                               NaN                  NaN
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                 122754               346458
# taxvaluedollarcnt                          360170               585529
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                      237416               239071
# taxamount                                 6735.88                10153
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.03711e+13                  NaN
#
#                                             2                    3      \
# parcelid                                 12098116             12643413
# logerror                                   -0.004               0.0218
# transactiondate               2016-01-01 00:00:00  2016-01-02 00:00:00
# airconditioningtypeid                           1                    1
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     3                    2
# bedroomcnt                                      2                    2
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                           4                    4
# calculatedbathnbr                               3                    2
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet                 2217                  839
# finishedsquarefeet12                         2217                  839
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6037                 6037
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                     3                    2
# garagecarcnt                                  NaN                  NaN
# garagetotalsqft                               NaN                  NaN
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                           2                    2
# latitude                              3.41363e+07          3.37558e+07
# longitude                            -1.18175e+08         -1.18309e+08
# lotsizesquarefeet                           11423                70859
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                    0100                 010C
# propertylandusetypeid                         261                  266
# propertyzoningdesc                           PSR6                 LAR3
# rawcensustractandblock                6.03746e+07           6.0373e+07
# regionidcity                                47019                12447
# regionidcounty                               3101                 3101
# regionidneighborhood                       275411                54300
# regionidzip                                 96293                96222
# roomcnt                                         0                    0
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                  NaN
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                         1                    1
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1940                 1987
# numberofstories                               NaN                  NaN
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                  61994               171518
# taxvaluedollarcnt                          119906               244880
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                       57912                73362
# taxamount                                 11484.5              3048.74
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.03746e+13           6.0373e+13
#
#                                             4                    5      \
# parcelid                                 14432541             11509835
# logerror                                   -0.005              -0.2705
# transactiondate               2016-01-02 00:00:00  2016-01-02 00:00:00
# airconditioningtypeid                         NaN                    1
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                   2.5                    4
# bedroomcnt                                      4                    4
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                         NaN                    1
# calculatedbathnbr                             2.5                    4
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet                 2283                 3067
# finishedsquarefeet12                         2283                 3067
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6059                 6037
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                     2                    4
# garagecarcnt                                    2                  NaN
# garagetotalsqft                               598                  NaN
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                         NaN                    2
# latitude                              3.34856e+07          3.38701e+07
# longitude                              -1.177e+08         -1.18403e+08
# lotsizesquarefeet                            6000                 2708
# poolcnt                                         1                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                     1                  NaN
# propertycountylandusecode                     122                 0100
# propertylandusetypeid                         261                  261
# propertyzoningdesc                            NaN               HBR3YY
# rawcensustractandblock                6.05904e+07          6.03762e+07
# regionidcity                                17686                29712
# regionidcounty                               1286                 3101
# regionidneighborhood                          NaN                  NaN
# regionidzip                                 96961                96109
# roomcnt                                         8                    0
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                             1                  NaN
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                       NaN                    1
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1981                 1982
# numberofstories                                 2                  NaN
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                 169574               880650
# taxvaluedollarcnt                          434551          2.44795e+06
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                      264977           1.5673e+06
# taxamount                                 5488.96              27126.6
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.05904e+13          6.03762e+13
#
#                                             6                    7      \
# parcelid                                 12286022             17177301
# logerror                                    0.044               0.1638
# transactiondate               2016-01-02 00:00:00  2016-01-02 00:00:00
# airconditioningtypeid                         NaN                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     1                  2.5
# bedroomcnt                                      2                    3
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                           7                  NaN
# calculatedbathnbr                               1                  2.5
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  853
# calculatedfinishedsquarefeet                 1297                 1763
# finishedsquarefeet12                         1297                 1763
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  853
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6037                 6111
# fireplacecnt                                  NaN                    1
# fullbathcnt                                     1                    2
# garagecarcnt                                  NaN                    2
# garagetotalsqft                               NaN                    0
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                           7                  NaN
# latitude                              3.38995e+07          3.42072e+07
# longitude                            -1.18213e+08         -1.19166e+08
# lotsizesquarefeet                            6677                  NaN
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                    0100                 1129
# propertylandusetypeid                         261                  266
# propertyzoningdesc                          CORH*                  NaN
# rawcensustractandblock                6.03754e+07            6.111e+07
# regionidcity                                24174                13150
# regionidcounty                               3101                 2061
# regionidneighborhood                          NaN                  NaN
# regionidzip                                 96091                97101
# roomcnt                                         0                    6
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                    1
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                         1                  NaN
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1939                 1994
# numberofstories                               NaN                    2
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                  64549               107000
# taxvaluedollarcnt                          111521               306000
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                       46972               199000
# taxamount                                 2304.97               3745.5
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.03754e+13            6.111e+13
#
#                                             8                    9      \
# parcelid                                 14739064             14677559
# logerror                                   -0.003               0.0843
# transactiondate               2016-01-02 00:00:00  2016-01-03 00:00:00
# airconditioningtypeid                         NaN                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     1                    2
# bedroomcnt                                      2                    2
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                         NaN                  NaN
# calculatedbathnbr                               1                    2
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet                  796                 1260
# finishedsquarefeet12                          796                 1260
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6059                 6059
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                     1                    2
# garagecarcnt                                    1                    1
# garagetotalsqft                                 0                    0
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                         NaN                  NaN
# latitude                              3.35496e+07          3.36127e+07
# longitude                            -1.17678e+08         -1.17742e+08
# lotsizesquarefeet                             NaN                  NaN
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                      34                   34
# propertylandusetypeid                         266                  266
# propertyzoningdesc                            NaN                  NaN
# rawcensustractandblock                6.05904e+07          6.05906e+07
# regionidcity                                25459                46098
# regionidcounty                               1286                 1286
# regionidneighborhood                          NaN                  NaN
# regionidzip                                 96987                96963
# roomcnt                                         0                    5
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                  NaN
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                       NaN                  NaN
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1984                 1977
# numberofstories                               NaN                    1
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                  66834               109977
# taxvaluedollarcnt                          210064               190960
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                      143230                80983
# taxamount                                 2172.88              1940.26
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.05904e+13          6.05906e+13
#
#                                      ...                         90265  \
# parcelid                             ...                      12062080
# logerror                             ...                       -0.3769
# transactiondate                      ...           2016-12-30 00:00:00
# airconditioningtypeid                ...                             1
# architecturalstyletypeid             ...                           NaN
# basementsqft                         ...                           NaN
# bathroomcnt                          ...                             1
# bedroomcnt                           ...                             2
# buildingclasstypeid                  ...                           NaN
# buildingqualitytypeid                ...                             4
# calculatedbathnbr                    ...                             1
# decktypeid                           ...                           NaN
# finishedfloor1squarefeet             ...                           NaN
# calculatedfinishedsquarefeet         ...                           860
# finishedsquarefeet12                 ...                           860
# finishedsquarefeet13                 ...                           NaN
# finishedsquarefeet15                 ...                           NaN
# finishedsquarefeet50                 ...                           NaN
# finishedsquarefeet6                  ...                           NaN
# fips                                 ...                          6037
# fireplacecnt                         ...                           NaN
# fullbathcnt                          ...                             1
# garagecarcnt                         ...                           NaN
# garagetotalsqft                      ...                           NaN
# hashottuborspa                       ...                           NaN
# heatingorsystemtypeid                ...                             2
# latitude                             ...                   3.41546e+07
# longitude                            ...                   -1.1826e+08
# lotsizesquarefeet                    ...                           NaN
# poolcnt                              ...                           NaN
# poolsizesum                          ...                           NaN
# pooltypeid10                         ...                           NaN
# pooltypeid2                          ...                           NaN
# pooltypeid7                          ...                           NaN
# propertycountylandusecode            ...                          010C
# propertylandusetypeid                ...                           266
# propertyzoningdesc                   ...                          GLR4
# rawcensustractandblock               ...                    6.0373e+07
# regionidcity                         ...                         45457
# regionidcounty                       ...                          3101
# regionidneighborhood                 ...                        275884
# regionidzip                          ...                         96322
# roomcnt                              ...                             0
# storytypeid                          ...                           NaN
# threequarterbathnbr                  ...                           NaN
# typeconstructiontypeid               ...                           NaN
# unitcnt                              ...                             1
# yardbuildingsqft17                   ...                           NaN
# yardbuildingsqft26                   ...                           NaN
# yearbuilt                            ...                          2012
# numberofstories                      ...                           NaN
# fireplaceflag                        ...                           NaN
# structuretaxvaluedollarcnt           ...                        106689
# taxvaluedollarcnt                    ...                        266825
# assessmentyear                       ...                          2015
# landtaxvaluedollarcnt                ...                        160136
# taxamount                            ...                       3075.18
# taxdelinquencyflag                   ...                           NaN
# taxdelinquencyyear                   ...                           NaN
# censustractandblock                  ...                    6.0373e+13
#
#                                             90266                90267  \
# parcelid                                 12265636             17109680
# logerror                                   -0.003                0.001
# transactiondate               2016-12-30 00:00:00  2016-12-30 00:00:00
# airconditioningtypeid                         NaN                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     2                    2
# bedroomcnt                                      4                    4
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                           7                  NaN
# calculatedbathnbr                               2                    2
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                 1430
# calculatedfinishedsquarefeet                 1496                 1830
# finishedsquarefeet12                          NaN                 1830
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                         1496                  NaN
# finishedsquarefeet50                          NaN                 1430
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6037                 6111
# fireplacecnt                                  NaN                    1
# fullbathcnt                                     2                    2
# garagecarcnt                                  NaN                    1
# garagetotalsqft                               NaN                  390
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                         NaN                  NaN
# latitude                              3.38987e+07          3.42689e+07
# longitude                            -1.18242e+08         -1.19181e+08
# lotsizesquarefeet                            4900                 6402
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                    0200                 1111
# propertylandusetypeid                         246                  261
# propertyzoningdesc                          CORM*                  NaN
# rawcensustractandblock                6.03754e+07            6.111e+07
# regionidcity                                24174                34543
# regionidcounty                               3101                 2061
# regionidneighborhood                          NaN                  NaN
# regionidzip                                 96090                97084
# roomcnt                                         0                    7
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                  NaN
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                         2                  NaN
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1953                 1964
# numberofstories                               NaN                    1
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                  19554               180034
# taxvaluedollarcnt                           32581               300054
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                       13027               120020
# taxamount                                 6137.29              3172.68
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.03754e+13            6.111e+13
#
#                                             90268                90269  \
# parcelid                                 12268527             12920746
# logerror                                  -0.0151               0.0344
# transactiondate               2016-12-30 00:00:00  2016-12-30 00:00:00
# airconditioningtypeid                           1                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     3                    2
# bedroomcnt                                      3                    3
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                           4                    4
# calculatedbathnbr                               3                    2
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet                 2438                 1448
# finishedsquarefeet12                         2438                 1448
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6037                 6037
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                     3                    2
# garagecarcnt                                  NaN                  NaN
# garagetotalsqft                               NaN                  NaN
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                           2                    2
# latitude                               3.3917e+07          3.40989e+07
# longitude                            -1.18241e+08         -1.17875e+08
# lotsizesquarefeet                            5001                 7594
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                    0100                 0100
# propertylandusetypeid                         261                  261
# propertyzoningdesc                          CORL*            CVR17500*
# rawcensustractandblock                6.03754e+07           6.0374e+07
# regionidcity                                24174                24245
# regionidcounty                               3101                 3101
# regionidneighborhood                          NaN                  NaN
# regionidzip                                 96092                96473
# roomcnt                                         0                    0
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                  NaN
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                         1                    1
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1943                 1959
# numberofstories                               NaN                  NaN
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                 192373               141700
# taxvaluedollarcnt                          315288               405000
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                      122915               263300
# taxamount                                 5853.81              5311.03
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.03754e+13           6.0374e+13
#
#                                             90270                90271  \
# parcelid                                 10774160             12046695
# logerror                                  -0.0356                0.007
# transactiondate               2016-12-30 00:00:00  2016-12-30 00:00:00
# airconditioningtypeid                           1                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     1                    3
# bedroomcnt                                      1                    3
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                           4                    4
# calculatedbathnbr                               1                    3
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet                  653                 2856
# finishedsquarefeet12                          653                 2856
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6037                 6037
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                     1                    3
# garagecarcnt                                  NaN                  NaN
# garagetotalsqft                               NaN                  NaN
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                           2                    2
# latitude                               3.4203e+07          3.41987e+07
# longitude                            -1.18562e+08         -1.18225e+08
# lotsizesquarefeet                           93676                 9343
# poolcnt                                         1                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                     1                  NaN
# propertycountylandusecode                    010C                 0100
# propertylandusetypeid                         266                  261
# propertyzoningdesc                        LARD1.5               GLR1RY
# rawcensustractandblock                6.03713e+07           6.0373e+07
# regionidcity                                12447                45457
# regionidcounty                               3101                 3101
# regionidneighborhood                        40548               274580
# regionidzip                                 96364                96327
# roomcnt                                         0                    0
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                  NaN
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                         1                    1
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1979                 1965
# numberofstories                               NaN                  NaN
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                  43800               117893
# taxvaluedollarcnt                          191000               161111
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                      147200                43218
# taxamount                                 2495.24              1886.54
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock                   6.03713e+13           6.0373e+13
#
#                                             90272                90273  \
# parcelid                                 12995401             11402105
# logerror                                  -0.2679               0.0602
# transactiondate               2016-12-30 00:00:00  2016-12-30 00:00:00
# airconditioningtypeid                         NaN                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                     2                    2
# bedroomcnt                                      4                    2
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                           7                    4
# calculatedbathnbr                               2                    2
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet                 2617                 1034
# finishedsquarefeet12                          NaN                 1034
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                         2617                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                         6037                 6037
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                     2                    2
# garagecarcnt                                  NaN                  NaN
# garagetotalsqft                               NaN                  NaN
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                         NaN                    2
# latitude                              3.40757e+07          3.39639e+07
# longitude                            -1.18026e+08         -1.18367e+08
# lotsizesquarefeet                            6865                20033
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                    0200                 010C
# propertylandusetypeid                         246                  266
# propertyzoningdesc                         EMR3YY                INR4*
# rawcensustractandblock                6.03743e+07           6.0376e+07
# regionidcity                                51861                45888
# regionidcounty                               3101                 3101
# regionidneighborhood                          NaN                  NaN
# regionidzip                                 96478                96133
# roomcnt                                         0                    0
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                  NaN
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                         2                    1
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                    1924                 1981
# numberofstories                               NaN                  NaN
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt                  22008               132991
# taxvaluedollarcnt                           38096               165869
# assessmentyear                               2015                 2015
# landtaxvaluedollarcnt                       16088                32878
# taxamount                                  1925.7              2285.57
# taxdelinquencyflag                              Y                  NaN
# taxdelinquencyyear                             14                  NaN
# censustractandblock                   6.03743e+13           6.0376e+13
#
#                                             90274
# parcelid                                 12566293
# logerror                                   0.4207
# transactiondate               2016-12-30 00:00:00
# airconditioningtypeid                         NaN
# architecturalstyletypeid                      NaN
# basementsqft                                  NaN
# bathroomcnt                                     1
# bedroomcnt                                      3
# buildingclasstypeid                           NaN
# buildingqualitytypeid                           7
# calculatedbathnbr                               1
# decktypeid                                    NaN
# finishedfloor1squarefeet                      NaN
# calculatedfinishedsquarefeet                 1524
# finishedsquarefeet12                         1524
# finishedsquarefeet13                          NaN
# finishedsquarefeet15                          NaN
# finishedsquarefeet50                          NaN
# finishedsquarefeet6                           NaN
# fips                                         6037
# fireplacecnt                                  NaN
# fullbathcnt                                     1
# garagecarcnt                                  NaN
# garagetotalsqft                               NaN
# hashottuborspa                                NaN
# heatingorsystemtypeid                           7
# latitude                              3.38389e+07
# longitude                            -1.18219e+08
# lotsizesquarefeet                            5124
# poolcnt                                       NaN
# poolsizesum                                   NaN
# pooltypeid10                                  NaN
# pooltypeid2                                   NaN
# pooltypeid7                                   NaN
# propertycountylandusecode                    0100
# propertylandusetypeid                         261
# propertyzoningdesc                          CARS*
# rawcensustractandblock                6.03754e+07
# regionidcity                                  NaN
# regionidcounty                               3101
# regionidneighborhood                          NaN
# regionidzip                                 96244
# roomcnt                                         0
# storytypeid                                   NaN
# threequarterbathnbr                           NaN
# typeconstructiontypeid                        NaN
# unitcnt                                         1
# yardbuildingsqft17                            NaN
# yardbuildingsqft26                            NaN
# yearbuilt                                    1947
# numberofstories                               NaN
# fireplaceflag                                 NaN
# structuretaxvaluedollarcnt                  66258
# taxvaluedollarcnt                          163037
# assessmentyear                               2015
# landtaxvaluedollarcnt                       96779
# taxamount                                 2560.96
# taxdelinquencyflag                            NaN
# taxdelinquencyyear                            NaN
# censustractandblock                   6.03754e+13
#
# [60 rows x 90275 columns]

# %% [markdown]
# ### Datatypes Visulization

# %%
data_type_df = pd.DataFrame(merged.dtypes.value_counts()).reset_index().rename(columns={"index":"variableType", 0:"count"})
fig, ax = plt.subplots()
fig.set_size_inches(20,5)
sn.barplot(data=data_type_df, x='variableType', y='count', ax=ax, color = '#34495e')
#ax.set(xlabel = 'Variable Type', ylabel='Count', title='Variables Count Across Datatype')

# %% [markdown]
# ### Missing Value Analysis

# %%
missing_value_columns = merged.columns[merged.isnull().any()].tolist()
msno.bar(merged[missing_value_columns], figsize = (20,8), color='#34495e', fontsize= 12, labels= True)

# %%
msno.matrix(merged[missing_value_columns], width_ratios=(10,1), \
            figsize=(20,8), color = (0,0,0), fontsize= 12, sparkline=True, labels=True)

# %%
msno.heatmap(merged[missing_value_columns], figsize=(20,20))

# %% [markdown]
# ### Top Features Selection

# %%
from sklearn import model_selection, preprocessing
import xgboost as xgb
import warnings
warnings.filterwarnings("ignore")

# %%
mergedFilterd = merged.fillna(-999)
for f in mergedFilterd.columns:
    if mergedFilterd[f].dtype=='object':
        lbl = preprocessing.LabelEncoder()                         
        lbl.fit(list(mergedFilterd[f].values))                               #fill label encoder  
        mergedFilterd[f] = lbl.transform(list(mergedFilterd[f].values))      #fill with 0

# %%
train_y = mergedFilterd['logerror'].values
train_X = mergedFilterd.drop(['parcelid', 'transactiondate', 'logerror'], axis=1)

# %%
xgb_params = {
    'eta':0.05,
    'max_depth':8,
    'subsample':0.7,
    'colsample_bytree':0.7,
    'objective':'reg:linear',
    'evalmetric': 'rmse',
    'silent':1
}
dtrain = xgb.DMatrix(train_X, train_y, feature_names = train_X.columns.values) #load data 
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=100)

# %%
featureImportance = model.get_fscore()
features = pd.DataFrame()
features['features'] = featureImportance.keys()
features['importance'] = featureImportance.values()
features.sort_values(by=['importance'], ascending=False, inplace=True)
fig,ax = plt.subplots()
fig.set_size_inches(20,10)
plt.xticks(rotation=90)
sn.barplot(data=features.head(15), x='importance', y='features', ax=ax, orient='h', color='#34495e')

# %%
features.head(5)
# Out:
#                         features  importance
# 7   calculatedfinishedsquarefeet         790
# 11                      latitude         684
# 24             lotsizesquarefeet         597
# 2                      longitude         560
# 12    structuretaxvaluedollarcnt         522

# %% [markdown]
# ### Correlation Analysis

# %%
topFeatures = features['features'].tolist()[:20]
corrMatt = merged[topFeatures].corr()
mask = np.array(corrMatt)
mask[np.tril_indices_from(mask)] = False 
fig, ax = plt.subplots()
fig.set_size_inches(20,10)
sn.heatmap(corrMatt, mask=mask, vmax=.8, square=True)

# %%
mask
# Out:
# array([[ 0.00000000e+00,  9.32097026e-03, -4.87698257e-02,
#         -2.23685709e-02,  7.16488519e-01,  5.89022465e-01,
#          4.58550189e-01,  6.00018181e-01,  7.72552605e-01,
#          6.32034654e-01,  2.11640900e-01,  1.00000000e+00,
#          2.28895066e-02,  5.86767962e-02,  5.87925683e-02,
#         -1.58691131e-01, -4.18338597e-02,  5.96669511e-02,
#          1.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  9.19478307e-02,
#         -5.94096577e-01, -1.35478096e-02, -7.84108737e-02,
#         -1.47394117e-01, -1.12393595e-01,  2.27110129e-02,
#          6.63310558e-02, -7.47465984e-03,  1.08039925e-02,
#          2.04810810e-04, -7.01182362e-02, -7.04581751e-02,
#         -1.34658567e-01, -8.70537169e-03, -4.17596086e-01,
#          4.39168682e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -6.57071814e-02,  8.65499675e-03, -2.20377098e-02,
#         -3.40302275e-02, -2.13467292e-02, -1.96835157e-04,
#         -1.13983710e-01,  1.18078170e-01, -4.67064051e-02,
#         -3.74758593e-03, -7.90999731e-02, -7.85026060e-02,
#         -8.65151132e-02, -1.18549814e-02, -9.07727585e-02,
#          1.25495200e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -5.98065422e-02, -3.51536760e-02,
#         -4.08737713e-03, -2.46816299e-02, -1.83465961e-02,
#         -4.87907384e-03,  6.89770095e-02, -2.11179212e-02,
#          3.68014436e-02, -3.27581773e-01, -3.25381075e-01,
#          1.35084271e-01,  9.95973253e-03,  4.15024647e-01,
#         -6.16080002e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  7.95013536e-01,
#          6.23291904e-01,  8.26052216e-01,  5.86640601e-01,
#          3.05405302e-01,  2.99695983e-01,  7.44048406e-01,
#          2.10612151e-03,  3.81094657e-02,  3.85073031e-02,
#         -1.05381730e-01, -3.07089593e-02, -4.73237194e-02,
#          4.23237974e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          9.02712529e-01,  9.49375838e-01,  4.61899537e-01,
#          2.39117936e-01,  1.15647189e-01,  6.12495725e-01,
#          1.43351731e-03, -3.10461270e-02, -3.03956267e-02,
#         -4.20049657e-02, -2.66245554e-02, -2.82510437e-02,
#          2.91227171e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  9.55335769e-01,  3.53806390e-01,
#          1.73205291e-01,  3.94926467e-02,  4.80463118e-01,
#          6.80239379e-03, -2.03656577e-03, -1.80109150e-03,
#         -1.13484174e-02, -1.37340436e-02,  2.71691210e-02,
#          1.94817664e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  4.76362838e-01,
#          2.41329204e-01,  1.40939510e-01,  6.26051888e-01,
#          5.68935212e-03,  1.24417821e-02,  1.30388661e-02,
#         -4.67084754e-02, -2.13065437e-02, -1.10192840e-03,
#          2.87585939e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          6.46119839e-01,  3.68061368e-01,  7.99372012e-01,
#          1.22646179e-02,  9.71273435e-03,  1.30776118e-02,
#         -2.59747637e-01, -3.72421513e-02, -3.74786635e-02,
#          6.33630672e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  4.08712077e-02,  6.57598886e-01,
#          1.48742515e-02,  2.41896311e-02,  2.81700188e-02,
#         -2.57358574e-02, -2.21655805e-02,  7.53268984e-02,
#          6.15171617e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.58530089e-01,
#          4.28288278e-02,  2.43203480e-01,  2.44000554e-01,
#         -4.24891001e-01, -4.83594418e-02, -7.48846095e-02,
#          1.51646451e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          2.33190624e-02,  7.65232226e-02,  7.66929481e-02,
#         -1.96411483e-01, -4.16785373e-02,  6.07561538e-02,
#                     nan],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  5.40505873e-02,  5.38076504e-02,
#         -1.04359000e-02, -9.44581730e-03,  1.38339515e-02,
#          5.65353156e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  9.99821942e-01,
#         -6.38693915e-02, -3.12581500e-02,  8.00300409e-01,
#          1.08255549e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -4.44722751e-02, -3.13883525e-02,  7.97531055e-01,
#          1.07971578e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  3.76034900e-02,  8.10805029e-03,
#         -2.12023775e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -2.80137149e-02,
#         -6.38335104e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -4.19820798e-03],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00]])

# %%
corrMatt.head(5)
# Out:
#                               calculatedfinishedsquarefeet  latitude  \
# calculatedfinishedsquarefeet                      1.000000  0.009321
# latitude                                          0.009321  1.000000
# lotsizesquarefeet                                -0.048770  0.091948
# longitude                                        -0.022369 -0.594097
# structuretaxvaluedollarcnt                        0.716489 -0.013548
#
#                               lotsizesquarefeet  longitude  \
# calculatedfinishedsquarefeet          -0.048770  -0.022369
# latitude                               0.091948  -0.594097
# lotsizesquarefeet                      1.000000  -0.065707
# longitude                             -0.065707   1.000000
# structuretaxvaluedollarcnt             0.008655  -0.059807
#
#                               structuretaxvaluedollarcnt  taxamount  \
# calculatedfinishedsquarefeet                    0.716489   0.589022
# latitude                                       -0.013548  -0.078411
# lotsizesquarefeet                               0.008655  -0.022038
# longitude                                      -0.059807  -0.035154
# structuretaxvaluedollarcnt                      1.000000   0.795014
#
#                               landtaxvaluedollarcnt  taxvaluedollarcnt  \
# calculatedfinishedsquarefeet               0.458550           0.600018
# latitude                                  -0.147394          -0.112394
# lotsizesquarefeet                         -0.034030          -0.021347
# longitude                                 -0.004087          -0.024682
# structuretaxvaluedollarcnt                 0.623292           0.826052
#
#                               bathroomcnt  bedroomcnt  yearbuilt  \
# calculatedfinishedsquarefeet     0.772553    0.632035   0.211641
# latitude                         0.022711    0.066331  -0.007475
# lotsizesquarefeet               -0.000197   -0.113984   0.118078
# longitude                       -0.018347   -0.004879   0.068977
# structuretaxvaluedollarcnt       0.586641    0.305405   0.299696
#
#                               finishedsquarefeet12  regionidzip  \
# calculatedfinishedsquarefeet              1.000000     0.022890
# latitude                                  0.010804     0.000205
# lotsizesquarefeet                        -0.046706    -0.003748
# longitude                                -0.021118     0.036801
# structuretaxvaluedollarcnt                0.744048     0.002106
#
#                               rawcensustractandblock  censustractandblock  \
# calculatedfinishedsquarefeet                0.058677             0.058793
# latitude                                   -0.070118            -0.070458
# lotsizesquarefeet                          -0.079100            -0.078503
# longitude                                  -0.327582            -0.325381
# structuretaxvaluedollarcnt                  0.038109             0.038507
#
#                               buildingqualitytypeid  regionidcity  \
# calculatedfinishedsquarefeet              -0.158691     -0.041834
# latitude                                  -0.134659     -0.008705
# lotsizesquarefeet                         -0.086515     -0.011855
# longitude                                  0.135084      0.009960
# structuretaxvaluedollarcnt                -0.105382     -0.030709
#
#                               airconditioningtypeid  finishedsquarefeet15
# calculatedfinishedsquarefeet               0.059667              1.000000
# latitude                                  -0.417596              0.043917
# lotsizesquarefeet                         -0.090773              0.125495
# longitude                                  0.415025             -0.061608
# structuretaxvaluedollarcnt                -0.047324              0.423238

# %% [markdown]
# ### Multicollinearity Analysis

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings
warnings.filterwarnings('ignore')

# %%
def calculate_vif_(X):
    variables = list(X.columns)
    vif = {}
    for ix, variable in enumerate(list(X.columns)):
        vif[variable] = variance_inflation_factor(exog=X.values, exog_idx=ix)
    return vif

# %%
numericalCol = []
for f in merged.columns:
    if merged[f].dtype!='object' and f not in ['parcelid', 'transactiondate', 'logerror']:
        numericalCol.append(f)
mergedFilterd = merged[numericalCol].fillna(-999) #？why -999
vifDict = calculate_vif_(mergedFilterd)

# %%
vifDf = pd.DataFrame()
vifDf['variables'] = vifDict.keys()
vifDf['vifScore'] = vifDict.values()
vifDf.sort_values(by=['vifScore'], ascending=False, inplace=True)
vifDf.head(5)
# Out:
#                        variables      vifScore
# 11          finishedsquarefeet12  2.817303e+11
# 10  calculatedfinishedsquarefeet  6.320323e+09
# 25                       poolcnt  6.110627e+09
# 29                   pooltypeid7  4.518148e+09
# 13          finishedsquarefeet15  2.163587e+09

# %%
validVariables = vifDf[vifDf['vifScore']<=5]
variablesWithMC = vifDf[vifDf['vifScore']>5]

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(20,8)
sn.barplot(data=validVariables, x='vifScore', y='variables', ax=ax1, orient='h', color='#34495e')
sn.barplot(data=variablesWithMC.head(5), x='vifScore', y='variables', ax=ax2, orient='h', color='#34495e')
ax1.set(xlabel='VIF Scores', ylabel='Features',title="Valid Variables Without Multicollinearity")
ax2.set(xlabel='VIF Scores', ylabel='Features',title="Variables Which Exhibit Multicollinearity") #?
# Out:
# [Text(0,0.5,'Features'),
#  Text(0.5,0,'VIF Scores'),
#  Text(0.5,1,'Variables Which Exhibit Multicollinearity')]

# %% [markdown]
# ### Univariate Analysis
# #### Dependent variable logerror follows nice normal distribution

# %%
ulimit = np.percentile(merged.logerror.values, 99)
llimit = np.percentile(merged.logerror.values, 1) #get rid of outlier

# %%
merged['logerror'].ix[merged['logerror']>ulimit] = ulimit
merged['logerror'].ix[merged['logerror']<llimit] = llimit

# %%
fig,ax = plt.subplots()
fig.set_size_inches(20,5)
sn.distplot(merged.logerror.values, bins=50,kde=False,color="#34495e",ax=ax)
ax.set(xlabel='logerror', ylabel='VIF Score',title="Distribution Of Dependent Variable")
# Out:
# [Text(0,0.5,'VIF Score'),
#  Text(0.5,0,'logerror'),
#  Text(0.5,1,'Distribution Of Dependent Variable')]

# %% [markdown]
# ### Bivariate Analysis

# %%
train.head(5)
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
train['year'] = train.transactiondate.map(lambda x: str(x).split('-')[0])
train['month'] = train.transactiondate.map(lambda x: str(x).split('-')[1])
train['day'] = train.transactiondate.map(lambda x: str(x).split('-')[2].split()[0])

# %%
train.head(5)
# Out:
#    parcelid  logerror transactiondate  year month day
# 0  11016594    0.0276      2016-01-01  2016    01  01
# 1  14366692   -0.1684      2016-01-01  2016    01  01
# 2  12098116   -0.0040      2016-01-01  2016    01  01
# 3  12643413    0.0218      2016-01-02  2016    01  02
# 4  14432541   -0.0050      2016-01-02  2016    01  02

# %%
traingroupedMonth = train.groupby(['month'])['logerror'].mean().to_frame().reset_index()
traingroupedDay = train.groupby(["day"])["logerror"].mean().to_frame().reset_index()

# %% [markdown]
# #### Month Analysis

# %%
traingroupedMonth
# Out:
#    month  logerror
# 0     01  0.015870
# 1     02  0.016082
# 2     03  0.009867
# 3     04  0.006605
# 4     05  0.006926
# 5     06  0.007172
# 6     07  0.011687
# 7     08  0.011573
# 8     09  0.016255
# 9     10  0.016342
# 10    11  0.014510
# 11    12  0.019122

# %%
fig,(ax1,ax2)= plt.subplots(nrows=2)
fig.set_size_inches(20,15)

sn.pointplot(x=traingroupedMonth['month'], y=traingroupedMonth['logerror'], data=traingroupedMonth, join=True, ax=ax1, color='#34495e')
ax1.set(xlabel='Month Of The Year', ylabel='Log Error',title="Average Log Error Across Month Of 2016",label='big')

sn.countplot(x=train['month'], data=train, ax=ax2, color='#34495e')
ax2.set(xlabel='Month Of The Year', ylabel='No Of Occurences',title="No Of Occurunces Across Month In 2016",label='big')
# Out:
# [Text(0,0.5,'No Of Occurences'),
#  Text(0.5,0,'Month Of The Year'),
#  Text(0.5,1,'No Of Occurunces Across Month In 2016'),
#  None]

# %% [markdown]
# #### Log Error Across Days Analysis

# %%
fig,(ax1,ax2)= plt.subplots(nrows=2)
fig.set_size_inches(20,15)

sn.pointplot(x=traingroupedDay["day"], y=traingroupedDay["logerror"], data=traingroupedDay, join=True,ax=ax1,color="#34495e")
ax1.set(xlabel='Day Of The Month', ylabel='Log Error',title="Average Log Error Across Days Of The Month In 2016",label='big')

sn.countplot(x=train["day"], data=train,ax=ax2,color="#34495e")
ax2.set(xlabel='Day Of The Month', ylabel='No Of Occurences',title="No Of Occurences Across Days Of The Month In 2016",label='big')
# Out:
# [Text(0,0.5,'No Of Occurences'),
#  Text(0.5,0,'Day Of The Month'),
#  Text(0.5,1,'No Of Occurences Across Days Of The Month In 2016'),
#  None]

# %% [markdown]
# ### No Of Storey Over The Years

# %% [markdown]
# #### It is quite interesting to notice people started building more of 2 or 3 storey buildings After 1950

# %%
fig,ax1= plt.subplots()
fig.set_size_inches(20,10)
merged["yearbuilt"] = merged["yearbuilt"].map(lambda x:str(x).split(".")[0])
yearMerged = merged.groupby(['yearbuilt', 'numberofstories'])["parcelid"].count().unstack('numberofstories').fillna(0)
yearMerged.plot(kind='bar', stacked=True,ax=ax1)

# %%
cols = ["bathroomcnt","bedroomcnt","roomcnt","numberofstories","logerror","calculatedfinishedsquarefeet"]
mergedFiltered = merged[cols].dropna() #why did he choose this features?
for col in cols:
    ulimit = np.percentile(mergedFiltered[col].values, 99.5)
    llimit = np.percentile(mergedFiltered[col].values, 0.5)
    mergedFiltered[col].ix[mergedFiltered[col]>ulimit] = ulimit
    mergedFiltered[col].ix[mergedFiltered[col]<llimit] = llimit

# %%
mergedFiltered.head(10)
# Out:
#     bathroomcnt  bedroomcnt  roomcnt  numberofstories  logerror  \
# 4           2.5         4.0      8.0              2.0   -0.0050
# 7           2.5         3.0      6.0              2.0    0.1638
# 9           2.0         2.0      5.0              1.0    0.0843
# 14          2.0         2.0      6.0              1.0   -0.0450
# 15          2.0         3.0      5.0              1.0    0.0020
# 16          2.5         3.0      6.0              2.0    0.0440
# 18          2.0         3.0      6.0              1.0   -0.0020
# 21          2.0         2.0      5.0              1.0    0.0218
# 22          2.0         4.0      7.0              1.0    0.0149
# 27          2.5         2.0      5.0              2.0    0.0080
#
#     calculatedfinishedsquarefeet
# 4                         2283.0
# 7                         1763.0
# 9                         1260.0
# 14                        1367.0
# 15                        1302.0
# 16                        1558.0
# 18                        1321.0
# 21                        1476.0
# 22                        1430.0
# 27                        1858.0

# %% [markdown]
# ### Calculated Finished Square Feet Vs Log Error

# %%
plt.figure(figsize=(8,8))
sn.jointplot(x=mergedFiltered.calculatedfinishedsquarefeet.values, y=mergedFiltered.logerror.values, size=15,kind="hex",color="#34495e")
plt.ylabel('Log Error', fontsize=12)
plt.xlabel('Calculated Finished Square Feet', fontsize=12)
plt.show()

# %% [markdown]
# ### Bedroom Count Vs Log Error

# %%
fig,ax= plt.subplots()
fig.set_size_inches(20,5)
sn.boxplot(x="bedroomcnt", y="logerror", data=mergedFiltered,ax=ax,color="#34495e")
ax.set(ylabel='Log Error',xlabel="Bedroom Count",title="Bedroom Count Vs Log Error")
# Out:
# [Text(0,0.5,'Log Error'),
#  Text(0.5,0,'Bedroom Count'),
#  Text(0.5,1,'Bedroom Count Vs Log Error')]

# %% [markdown]
# ### Bathroom Count Vs Log Error

# %%
fig,ax= plt.subplots()
fig.set_size_inches(20,5)
sn.boxplot(x="bathroomcnt", y="logerror", data=mergedFiltered,ax=ax,color="#34495e")
ax.set(ylabel='Log Error',xlabel="Bathroom Count",title="Bathroom Count Vs Log Error")
# Out:
# [Text(0,0.5,'Log Error'),
#  Text(0.5,0,'Bathroom Count'),
#  Text(0.5,1,'Bathroom Count Vs Log Error')]

# %% [markdown]
# ### Room Count Vs Log Error

# %%
fig,ax= plt.subplots()
fig.set_size_inches(20,5)
sn.boxplot(x="roomcnt", y="logerror", data=mergedFiltered,ax=ax,color="#34495e")
ax.set(ylabel='Log Error',xlabel="Room Count",title="Room Count Vs Log Error")
# Out:
# [Text(0,0.5,'Log Error'),
#  Text(0.5,0,'Room Count'),
#  Text(0.5,1,'Room Count Vs Log Error')]

# %% [markdown]
# ### No Of Storeys Vs Log Error

# %%
fig,ax= plt.subplots()
fig.set_size_inches(20,5)
sn.boxplot(x="numberofstories", y="logerror", data=mergedFiltered,ax=ax,color="#34495e")
ax.set(ylabel='Log Error',xlabel="No Of Storeys",title="No Of Storeys Vs Log Error")
# Out:
# [Text(0,0.5,'Log Error'),
#  Text(0.5,0,'No Of Storeys'),
#  Text(0.5,1,'No Of Storeys Vs Log Error')]

# %% [markdown]
# ### Bedroom Vs Bathroom Vs Log Error

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot
fig = pylab.figure()
fig.set_size_inches(20,10)
ax = Axes3D(fig)

ax.scatter(mergedFiltered.bathroomcnt, mergedFiltered.bedroomcnt, mergedFiltered.logerror, color = '#34495e')
ax.set_xlabel('Bathroom Count')
ax.set_ylabel('Bedroom Count')
ax.set_zlabel('Log Error');
pyplot.show()
